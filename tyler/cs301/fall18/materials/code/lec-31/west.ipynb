# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("bus.db")
conn

# %%
pd.read_sql("select Route, Lat, Lon from boarding order by lon ASC limit 1", conn)
# Out:
#    Route        Lat        Lon
# 0     55  42.995476 -89.564243

# %%
pd.read_sql("select * from boarding where Route = 55", conn)
# Out:
#     index  StopID  Route        Lat        Lon  DailyBoardings
# 0    1029    6100     55  43.053883 -89.475098           60.46
# 1    3464    4261     55  42.990502 -89.533087            3.69
# 2    3470    4310     55  42.989314 -89.540273            0.23
# 3    3489    4400     55  42.995476 -89.564243           59.31
# 4    3515    4519     55  42.988306 -89.545956            1.50
# 5    3527    4556     55  42.992870 -89.526778            0.69
# 6    3529    4559     55  42.987673 -89.553340            0.92
# 7    3541    4623     55  42.992557 -89.526432            1.38
# 8    3570    4732     55  42.990501 -89.534012            0.12
# 9    3599    4812     55  42.988076 -89.552983            0.58
# 10   3607    4838     55  42.994093 -89.519406            0.12
# 11   3631    4905     55  42.989036 -89.540667            0.23

# %%
df = pd.read_sql("select * from boarding", conn)
df
# Out:
#       index  StopID  Route        Lat        Lon  DailyBoardings
# 0         0    1163     27  43.073655 -89.385427            1.03
# 1         1    1163     47  43.073655 -89.385427            0.11
# 2         2    1163     75  43.073655 -89.385427            0.34
# 3         3    1164      6  43.106465 -89.340021           10.59
# 4         4    1167      3  43.077867 -89.369993            3.11
# 5         5    1167      4  43.077867 -89.369993            2.23
# 6         6    1167     10  43.077867 -89.369993            0.11
# 7         7    1167     38  43.077867 -89.369993            1.36
# 8         8    1169      3  43.089707 -89.329817           18.90
# 9         9    1169     37  43.089707 -89.329817            1.35
# 10       10    1169     38  43.089707 -89.329817           31.15
# 11       11    1177      2  43.096916 -89.363631            6.69
# 12       12    1177     28  43.096916 -89.363631            1.46
# ...

# %%
df.describe()
# Out:
#              index       StopID        Route          Lat          Lon  \
# count  3972.000000  3972.000000  3972.000000  3972.000000  3972.000000
# mean   1985.500000  3698.398792    32.141239    43.075374   -89.402466
# std    1146.761963  2995.200272    23.700705     0.026544     0.063686
# min       0.000000     5.000000     1.000000    42.987673   -89.564243
# 25%     992.750000  1208.750000    12.000000    43.062279   -89.450882
# 50%    1985.500000  2465.000000    28.000000    43.074719   -89.396970
# 75%    2978.250000  6539.500000    51.000000    43.090502   -89.358540
# max    3971.000000  9996.000000    84.000000    43.156741   -89.260469
#
#        DailyBoardings
# count     3972.000000
# mean        14.095463
# std         42.900325
# min          0.110000
# 25%          0.790000
# 50%          3.135000
# 75%         10.792500
# max        984.510000
