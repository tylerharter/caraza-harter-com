# %% [markdown]
# # Inheritance

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("bark")

    def __str__(self):
        return f"Dog {self.name}"

    def __repr__(self):
        return f"Dog('{self.name}')"

fido = Dog("Fido")
print(fido)
fido
# Out:
# Dog Fido
# Dog('Fido')

# %% [markdown]
# # ABC's
#
# https://docs.python.org/3/library/collections.abc.html#collections-abstract-base-classes

# %%
class Range:
    def __init__(self, bound1, bound2=None):
        if bound2 != None:
            self.lower = bound1
            self.upper = bound2
        else:
            self.lower = 0
            self.upper = bound1
            
    def __len__(self):
        return self.upper - self.lower
            
    def __getitem__(self, lookup):
        if not isinstance(lookup, int):
            raise NotImplementedError("slices not supported")
        if lookup < 0:
            raise NotImplementedError("negative not supported")
        if lookup >= len(self):
            raise IndexError("out of bounds")
        return self.lower + lookup

# %%
r = Range(2,5)

# %%
r.index(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/st/k8wrf6bs0v7c873ntgqhr1f40000gn/T/ipykernel_73823/3521274730.py in <module>
# ----> 1 r.index(3)
#
# AttributeError: 'Range' object has no attribute 'index'
