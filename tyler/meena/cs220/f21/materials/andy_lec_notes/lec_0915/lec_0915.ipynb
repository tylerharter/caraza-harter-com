# %%
# Warmup: calculate number of seconds in a year
60 * 1
# Out:
# 60

# %% [markdown]
# ## September 15: Operators
#
# Learning Objectives: After this lecture you will be able to...
#
# 4.1 Run Python Code
# - from the command line (interactive mode and script mode)
# - from IDLE (interactive mode and script mode)
# - from a Jupyter Notebook (combines interactive and script modes)
#
# 4.2 Evaluate numeric expressions containing mathematical operators
#
# 4.3 Evaluate string expressions containing string operators and escape characters
#
# 4.4 Recognize examples of different Python data types: int, float, str, bool
#
# 4.4 Evaluate boolean expressions that contain the operators and, or, not

# %% [markdown]
# Command Line: Running code from Terminal/PowerShell
# interactive mode (>>> )
#
# script mode (python fruits.py)

# %% [markdown]
# IDLE: Running code from the IDLE program
# Find this program on your computer and run it.
#
# interactive mode
#
# script mode

# %%
# Out:
# 300

# %% [markdown]
# Jupyter Notebooks: a mix between interactive and script<br>
# If many lines of code are entered, the last line is displayed

# %%
# enter in 3 different calculations such as 17 + 3 * 2

# %% [markdown]
# A print statement will always display its result

# %%
# enter the same 3 calculations, but with one or more inside a print statement

# %%
# The / operator does Division as a float. Try a few examples
print()
print()
print()

# %%
# The // operator does Integer division. Try a few examples
print()
print()
print()

# %%
# Sometimes / will display small numbers in scientific notation
# print out calcualtions that result in very small numbers
print(34 / 1000)
# Out:
# 0.034

# %%
# the modulus operator (%) gives the Integer Remainder
print( 15 % 7)
# try other examples

# %%
# use the modulus along with Integer Division to grab a certain digit of an integer
print((6834//10) % 10)
# Out:
# 3

# %%
# the wrong way to do exponentiation is ^

# %%
# the correct way to do exponentiation is **

# %% [markdown]
# ![precedence.png](attachment:precedence.png)

# %%
# what operation is higher? ** or - ?

# %% [markdown]
# Things to know about Strings

# %%
# Strings can be enclosed in '' or ""

# %%
# Strings can contain special escape characters that start with \
# \n is for newline
# \t is for tab
# \" is for a literal quotation mark

# %%
# the + operator concatenates two strings

# %%
# the * operator repeats a string

# %% [markdown]
# Boolean Operators
#
#
# ![boolean%20operators.png](attachment:boolean%20operators.png)

# %%
# try out and, or, not with True and False values
print(True and False)
# Out:
# False

# %%
# try comparison operators
print(3 < 7)
# Out:
# True

# %%
# try to compare two strings with < or >  or >= or <=

# %%
# practice using != (not equal) and == (is equal)

# %%
# compare two types for equality

# %%
# compound comparisons with and

# %%
# compound comparisons with or
