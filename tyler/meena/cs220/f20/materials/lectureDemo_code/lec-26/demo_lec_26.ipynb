# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
os.listdir(".")
# Out:
# ['testFileFinder',
#  'nums.txt',
#  'gen.py',
#  'short.txt',
#  'fileFinder.py',
#  'point.py',
#  'demo_lec_27.ipynb',
#  'point.json',
#  '.ipynb_checkpoints']

# %%
#Solution 1: bad solution because we do a lot of reading work before we do any addition (miss the bug)
f = open("nums.txt")
nums = list(f)
f.close()

total = 0
for num in nums:
    total += num

print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-82c2daad6135> in <module>
#       6 total = 0
#       7 for num in nums:
# ----> 8     total += num
#       9
#      10 print(total)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
#Solution 2: better solution because start adding immediately after reading numbers from each line 
#(catch bugs quickly)
f = open("nums.txt")

total = 0
for num in f:
    total += num

print(total)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6391210b68de> in <module>
#       4 total = 0
#       5 for num in f:
# ----> 6     total += num
#       7
#       8 print(total)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
#Solution 3: best solution because of using a generator to transform the incoming stream of numbers
def reader(path):
    f = open(path)
    for num in f:
        yield int(num)
    f.close()
    
total = 0
for val in reader("nums.txt"):
    total += val
    
print(total)
# Out:
# 2499965642
