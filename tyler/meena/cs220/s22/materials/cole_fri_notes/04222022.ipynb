# %%
import time
import requests
import os
import json
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Lab Review

# %% [markdown]
# Note: The lab changed slightly in the last 24 hours. I am basing this on the most recent version.

# %% [markdown]
# ## Segment 1

# %%
# Save https://coletnelson.us/cs220-api/classes/STATS_302 to a file called "STATS_302.json"

# %%
# How could we check if the file already exists before downloading?

# %% [markdown]
# ## Segment 2

# %%
# Read in the data from "movies_clean.csv"

# %%
# Get all movies in the year 2020

# %%
# Display just the information for the movie "Soul" using movies_2020
# Boolean Masking, loc, iloc

# %%
# Get the # of movies released by year.
# Bonus: Sort by Index vs Sort by Value

# %%
# We use & (and), | (or), ~ (not) when applying multiple masks.
# We must make sure to enclose our expressions in parentheses.

# %% [markdown]
# ## Segment 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://media.istockphoto.com/vectors/plates-and-detergent-for-washing-isolated-on-white-background-vector-vector-id976077210?k=20&m=976077210&s=612x612&w=0&h=EInLfzCXhlrDoqMM25jXQ2_j0ld8-C_PmQoUTVbPtm8=

# %% [markdown]
# ## Segment 4

# %%
# Grab Dates & Interests Rates for EE Bonds

# %% [markdown]
# https://www.treasurydirect.gov/indiv/research/indepth/ebonds/res_e_bonds_eeratesandterms_eebondsissued052005andafer.htm

# %% [markdown]
# ![image.png](attachment:image.png)
