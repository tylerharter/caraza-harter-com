# %%
# Warmup 1: Sort this dictionary by keys

# source: https://en.wikipedia.org/wiki/Big_Ten_Conference#Members (2021)

enrollments = { "Wisconsin": 45540, "Michigan": 47907, "Illinois": 52331,
        "Iowa": 30448, "Minnesota": 52017, "Ohio State": 61369, "Northwestern": 22316}

# %%
# Warmup 2: Sort the above dictionary by values

# %%
# Warmup 3: Sort this list of dictionaries by 'hours'
volunteers = [  {"name": "Skylar", "hours": 53}, 
             {"name":"Patrice", "hours": 72},
              {"name":"Gabriella", "hours": 45},
              {"name": "Jayden", "hours": 62}
             ]

# %%
# What is a lambda function? 
# an abstraction (shortcut) to a function
# remove the def, name, and return statement
# just describe the parameter and the return value

# %%
# Warmup 4: Sort the above list of dictionaries by 'name'

# %%
# Warmup 5: Sort this lists of strings by length of string
fruits = ["apple", "blueberry", "cherry", "date", "fig", "grapefruit"]

# %%
# Warmup 6: Sort this dictionary of lists by length of list
cities_by_county = {"Dane": ["Madison", "Sun Prairie", "Middleton", "Waunakee"],
                   "Milwaukee": ["Milwaukee", "West Allis", "Wauwatosa"],
                   "Rock": ["Janesville", "Beloit"],
                   "Waukesha": ["Brookfield"]}

# %% [markdown]
# ## November 03: Iterators and Comprehensions
#
# Learning Objectives:
#
# 25.1 Create list and dictionary comprehensions
#
# 25.2 Use the correct vocabulary to describe iteration
# - iterable, sequence, iterator
#
# 25.3 Determine if an object is an iterable, or if it is an iterator
# - try to use iter() to determine if an object is an iterable
# - try to use next() to determine if an object is an iterator
#
# 25.4 Use iterator/iterable language to open and process files

# %% [markdown]
# ### 25.1 Create list and dictionary comprehensions

# %%
# Given this list what kind of filtered list could we make from it? 
# By filtered, think about keeping certain words
fruits = ["apple", "blueberry", "cherry", "DATE", "FIG", "grapefruit"]
# Talk to your partner and come up with different ideas

# %%
# let's make some list comprehensions
# Tip:  Write them in reverse, naming the variable last

# %%
# Given this list of dictionaries, what kind of lists could we make from it?
# Talk to your partner and come up with different ideas
volunteers = [  {"name": "Skylar", "hours": 53}, 
             {"name":"Patrice", "hours": 72},
              {"name":"Gabriella", "hours": 45},
              {"name": "Jayden", "hours": 62}
             ]

# %%
# Given this dictionary, what other dictionary could we make?
cities_by_county = {"Dane": ["Madison", "Sun Prairie", "Middleton", "Waunakee"],
                   "Milwaukee": ["Milwaukee", "West Allis", "Wauwatosa"],
                   "Rock": ["Janesville", "Beloit"],
                   "Waukesha": ["Brookfield"]}

# %% [markdown]
# ### The syntax of Comprehensions

# %% [markdown]
# ![comprehensions.png](attachment:comprehensions.png)

# %%
# If/else...
# convert these Fahrenheit temps to an int in Celsius using C = 5/9 * (F-32)
temps = ["32", "45", "90", "212"]

# %%
# do it again, but change empty strings to None
# need to use an if else clause which must come before the 'for'
# new_list = [expression if conditional_expression else alternate_expression for val in iterable ]

# %%
scores_dict = {"Bob": [18, 72, 83], 
               "Cindy" : [27, 11, 55, 73, 87], 
               "Alice": [16, 33, 42, 89, 90], 
               "Meena": [39, 93, 9, 3, 55, 72, 19]}

# Create a dictionary where the key is the same, but the value is the average score

# %%
# For more reference
# https://www.w3schools.com/python/python_lists_comprehension.asp
# https://www.datacamp.com/community/tutorials/python-dictionary-comprehension

# %% [markdown]
# ### 25.2 Use the correct vocabulary to describe iteration

# %%
# How do those amazing comprehensions work?  They use what Python calls 'iterators'

# %% [markdown]
# ![vocab%20of%20iterators.png](attachment:vocab%20of%20iterators.png)

# %%
#
# try this out...and look at the slide above
# study this and practice using these words

nums = [1,2,3]          # nums is iterable
#k = iter(nums)          # iter takes an iterable object and makes an iterator to it

#print(k)                # k is a list iterator
#print(next(k))          # we can call next on an iterator to get a value
#what happens when we run out of things?

# %% [markdown]
# ## 25.3 Determine if an object is an iterable, or if it is an iterator
#
# - try to use iter() to determine if an object is an iterable
# - try to use next() to determine if an object is an iterator

# %%
# enumerate changes a list into a tuple with indexing
y = enumerate(["A", "B", "C"]) # y is iterable and iterator
it = iter(y)
print(next(y))
# Out:
# (0, 'A')

# %%
# An Int is ......
z = 3 # neither an iterator nor an iterable
# it = iter(z) # uncomment to see error

# %%
# A string is .....
name = "Stevie"
it = iter(name)
next(it)
# Out:
# 'S'

# %%
# Go into your Jupyter Notebook, make a new file and enter the following, 
# without the # at the start of each line
# name the file 'tips.txt'

# %% [raw]
# Debugging tips:
# Write just enough code that you can test, then run it.
# Don't try to solve the entire problem at once.
# Assume your code will not work.

# %%
file_path = "tips.txt"        # called a path b/c it might include C:\..\..\..
file_object = open(file_path)  

# is file_object iterable?  Yes! 
it = iter(file_object)
print(next(it))
#print(next(it))
#print(next(it))
#print(next(it))
#print(next(it))


# this is tedious, so we can use a for loop instead...do that below
# Q: how do we start over again with our file? 
# A: close it here, open it below
file_object.close()

# %%
file_path = 'tips.txt'
file_object = open(file_path)

#for line in file_object:
   # print(line)
    
# Q: why are there blank lines between lines of our output? 
# each line has a new line character "\n",   but then print adds another "\n"

# %%
# this time, let's use iter and next to get one thing at a time

# %% [markdown]
# ## More Reference about Comprehensions
