# %%
# Warmup 1:  Build a string using +=
dog = "Piper"
cat = "Dorami"
chicken = "Cluck Norris"

sentence = ""
sentence += "I have a dog named " + dog
sentence += " a cat named " + cat
sentence += " and a chicken named " + chicken
print(sentence)

# TODO: print the length of sentence using len
len(sentence)
# Out:
# I have a dog named Piper a cat named Dorami and a chicken named Cluck Norris
# 76

# %%
# Warmup 2a:  Read in the data for students
import project
help(project)
# Out:
# Help on module project:
#
# NAME
#     project
#
# FUNCTIONS
#     __init__()
#
#     count()
#         This function will return the number of records in the dataset
#
#     get_age(idx)
#         get_age(idx) returns the age of the student in row idx
#
#     get_lecture(idx)
#         get_lecture(idx) returns the lecture of the student in row idx
#
#     get_other_majors(idx)
#         get_other_majors(idx) returns the secondary major of the student in row idx
#
#     get_pet_owner(idx)
#         get_pet_owner(idx) returns whether student in row idx is a pet owner
#
#     get_piazza_topping(idx)
#         get_piazza_topping(idx) returns the preferred pizza toppings of the student in row idx
#
#     get_primary_major(idx)
#         get_primary_major(idx) returns the primary major of the student in row idx
#
#     get_procrastinator(idx)
#         get_procrastinator(idx) returns whether student in row idx is a procrastinator
#
#     get_runner(idx)
#         get_runner(idx) returns whether student in row idx is a runner
#
#     get_sleep_habit(idx)
#         get_sleep_habit(idx) returns the sleep habit of the student in row idx
#
#     get_zip_code(idx)
#         get_zip_code(idx) returns the residential zip code of the student in row idx
#
# DATA
#     __student__ = [{'Age': '19', 'Lecture': 'LEC002', 'Other majors': '', ...
#
# FILE
#     /Users/andrewkuemmel/cs220-s22/lectures/lec13_Feb25/project.py

# %%
# Warmup 2b: Write a for loop to find the number of students 
#            who are in LEC 003 and like pineapple on their pizza

frequency = 0
for idx in range(project.count()):
    # print (project.get_lecture(idx))
    if project.get_zip_code(idx) == '53706':
        if project.get_piazza_topping(idx) == "pineapple":
            frequency += 1
frequency
# Out:
# 29

# %%
# Warmup 2c: Write a for loop that prints out 
#            the min age of students in ZipCode 53706

min_age = None # 100000000 ....is hardcoding
for idx in range(project.count()):
    # print (project.get_lecture(idx))
    if project.get_zip_code(idx) == '53706':
        age = project.get_age(idx)
        if age == '':
            continue
        age = int(age)
        #print(age, type(age))
        if min_age == None or age < min_age:
            min_age = age
            
min_age
# Out:
# 17

# %% [markdown]
# ## October 6: Strings and 'for' loops
#
# ### Learning Objectives:
# - Compare two strings by hand using < or >
# - Recognize common string methods, explain what they do, and use them in Python code
# - Define the term sequence, name common sequence operations, and explain how a string is a sequence
# - Index and slice strings using correct syntax, including positive and negative indices
# - Read and Write code that uses a for loop to iterate over a string

# %% [markdown]
# ### Compare two strings by hand using < or >

# %% [markdown]
# ![string%20comparison.png](attachment:string%20comparison.png)

# %%
# Example 1a: Strings can be compared using !=, < and > 
print("cat" != "dog") # use !=
print("cat" < "dog") # use <
print("cat" > "dog") # use >
# Out:
# True
# True
# False

# %%
# Example 1b: Strings are compared one char at a time, using the ASCII table
# https://simple.wikipedia.org/wiki/ASCII

print("H" < "h")                 # upper case comes before lower case
print("dorm room" < "dormroom")  # space comes before 'r' in the ASCII table
print("base" < "baseball")      # strings that end come before strings that continue
print("11" < "2")               # strings of digits are compared one character at a time
# Out:
# True
# True
# True
# True

# %% [markdown]
# ### Recognize common string methods, explain what they do, and use them in Python code

# %% [markdown]
# ![string%20methods.png](attachment:string%20methods.png)

# %%
# Example 2a: strings have special functions that are part of the definition of a string
# These are called methods and are called with a '.', similar to modules


print(dog.upper())
print(dog)             # calling a method on a string does not mutate it
print(dog.lower())
print(dog.find("P"))
print(dog.startswith("Pip"))
print(dog.endswith("er"))
print(cat.replace("a", "e"))
print(cat)            # cat did not change


print()
# Out:
# PIPER
# Piper
# piper
# 0
# True
# True
# Doremi
# Dorami

# %%
# Example 2b: String methods can be called on 'literals'

print("Hello".upper())
print("Meet me at the bike racks".replace('e', 'o'))
# Out:
# HELLO
# Moot mo at tho biko racks

# %%
# Example 2c: stripping means to remove space, tab or enter from the ends
sentence2 = "\tgo ask them if they want to dance         \n\n"
print(sentence2)
print(sentence2.lstrip())
print(sentence2.rstrip())
print(sentence2.strip())
# Out:
# 	go ask them if they want to dance
#
#
# go ask them if they want to dance
#
#
# 	go ask them if they want to dance
# go ask them if they want to dance

# %%
# Example 2d: format allows for generic printing
email = "Dear {}, your grade for p1 is {}"
print("format:",email.format("Meena","A"))
print("format:",email.format("Andy","B"))
# Out:
# format: Dear Meena, your grade for p1 is A
# format: Dear Andy, your grade for p1 is B

# %% [markdown]
# ### Define the term sequence, name common sequence operations, and explain how a string is a sequence

# %% [markdown]
# ![sequences.png](attachment:sequences.png)

# %%
# len of a string
len(dog)
# Out:
# 5

# %% [markdown]
# ### Index and slice strings using correct syntax, including positive and negative indices

# %%
#indexing
day = "Friday"
print("012345")
print(day)
print(day[1]) #2nd  'day indexed at 1'
print(day[-1]) # last
print(day[-2]) # 2nd last
print(day[50]) # this won't work
# Out:
# 012345
# Friday
# r
# y
# a
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-d381b947c74f> in <module>
#       6 print(day[-1]) # last
#       7 print(day[-2]) # 2nd last
# ----> 8 print(day[50]) # this won't work
#
# IndexError: string index out of range

# %%
# slicing
print(day)
print(day[1:3]) # include 1, exclude 3
print(day[1:100])  # slicing is forgiving
print(day[1:])  # can skip 2nd number
print(day[:3])  # can skip 1st number
print(day[:])   # this, too!
print(day[-3:-1]) # can use negative indices
# Out:
# Friday
# ri
# riday
# riday
# Fri
# Friday
# da

# %% [markdown]
# ### Read and Write code that uses a for loop to iterate over a string

# %%
# for loop

for letter in day: #letter is a new variable that is the value of each iteration
    print(letter)
# Out:
# F
# r
# i
# d
# a
# y

# %%
# same thing using while loopos
index = 0
while index < len(day):
    print (day[index])
    index +=1
# Out:
# F
# r
# i
# d
# a
# y

# %%
# the 2nd variable must be defined
for a in b: #2nd var undefined
    print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b794ff0aaf3b> in <module>
#       1 # the 2nd variable must be defined
# ----> 2 for a in b: #2nd var undefined
#       3     print(a)
#
# NameError: name 'b' is not defined

# %%
# a for loop can be used with range being the length of a string
for idx in range(len(day)):
    print(day[idx])
# Out:
# F
# r
# i
# d
# a
# y

# %%
# an optional 3rd number is the increment
for idx in range(1, len(day), 2):  
    print(day[idx])
# Out:
# r
# d
# y

# %%
# Practice: Write a for loop to generate a string that makes an acronym

phrase = "National Collegiate Athletic Association"
acro = ""
for letter in phrase:
    if letter.upper() == letter: #its upper case N, C, A, A
        acro += letter
print(acro)
# Out:
# N C A A

# %%
# other string methods ....don't memorize all of them
# https://www.w3schools.com/python/python_ref_string.asp

# %% [markdown]
# ### Wordle !!

# %%
"pizza".find('a')
# Out:
# 4

# %%
"pizza".find('b')
# Out:
# -1

# %%
def get_wordle_results(guess):
    wordle_result = ""
    # use find 
    return wordle_result

max_num_guesses = 6
current_num_guesses = 1
word_of_the_day = "CRANE"

print("Welcome to PyWordle!")
print("You have 6 guesses to guess a 5 character word.")
print("X\tThe letter is not in the word.")
print("_\tThe letter is in the word, but in the wrong place.")
print("O\tThe letter is in the correct place!")

while current_num_guesses <= max_num_guesses:
    guess = input("Guess the word: ")
    guess = guess.upper()

    wordle_results = get_wordle_results(guess)
    print("{}\t{}".format(guess, wordle_results))
    current_num_guesses += 1

    
if current_num_guesses > max_num_guesses:
    print("Better luck next time!")
    print("The word was: {}".format(word_of_the_day))
else:
    print("You won in {} guesses!".format(current_num_guesses))
# Out:
# Welcome to PyWordle!
# You have 6 guesses to guess a 5 character word.
# X	The letter is not in the word.
# _	The letter is in the word, but in the wrong place.
# O	The letter is in the correct place!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-601fe6cb71ff> in <module>
#      14
#      15 while current_num_guesses <= max_num_guesses:
# ---> 16     guess = input("Guess the word: ")
#      17     guess = guess.upper()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     855                 "raw_input was called, but this frontend does not support input requests."
#     856             )
# --> 857         return self._input_request(str(prompt),
#     858             self._parent_ident,
#     859             self._parent_header,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     899             except KeyboardInterrupt:
#     900                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 901                 raise KeyboardInterrupt("Interrupted by user") from None
#     902             except Exception as e:
#     903                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# we will finish Wordle on Monday as a warmup
