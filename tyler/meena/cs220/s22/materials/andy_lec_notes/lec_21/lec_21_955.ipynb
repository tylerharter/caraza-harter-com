# %% [markdown]
# ## Warmups

# %%
# Warmup 1a: Question:  Is a {} all by itself a empty set or an empty dict?

thing1 = {}
print(type(thing1))
# Out:
# <class 'dict'>

# %%
# Warmup 1b:  Make it into the other thing by giving it a value
thing2 = {17}
print(type(thing2))
# Out:
# <class 'set'>

# %%
thing3 = {17:'seventeen'}
print(type(thing3))
# Out:
# <class 'dict'>

# %%
# Warmup 2: if S is a string and L is a list, which line definitely fails?
# S[-1] = "."  # this fails always, strings are immutable
# L[len(S)] = S # this fails IF len(S) is >= len(L)

# %%
# Discuss

# %% [markdown]
# ## October 25:  Objects, References, and Tuples
#
# After today's Lecture you will be able to:
#
# 21.1 Explain the difference between objects vs references, and stack vs heap.
#
# 21.2 Use tuples to store immutable sequences of values.
#
# 21.3 Use namedtuple (immutable) and recordclass (mutable) to store user-defined data objects.
#
# 21.4 Evaluate Python expressions that use 'is' and '==' to compare objects
#
# 21.5 Determine the side effects that occur when modifying parameters.

# %%
# Review of nested data structures:
# Put this into PythonTutor.com/visualize.html
webster = {
    "a": ["apple", "and", "ada"],
    "b": ["bike", "deBug"],
    "z": {"name": "zebra", "kind": "mammal"}
}

luny_list = [8, 9, webster]
luny_list.append(luny_list) # what?????
webster["L"] = luny_list

def foooo(everything):
    final_letter = everything[2]["z"]
    #print(????) #see Wednesday's worksheet.....sample exam questions
    
foooo(luny_list)

# %% [markdown]
# ![objects%20and%20references.png](attachment:objects%20and%20references.png)

# %% [markdown]
# ### 21.1 Explain the difference between objects vs references, and stack vs heap.

# %%
# Objects are locations in memory that store data 

# References are variables that store memory locations

# The stack is a segmented part of memory that stores variable refrences from each frame

# The heap is a big block of memory space that stores data structures

# %%
# Let's take a look at the slides for today

# %% [markdown]
# ### 21.2 Use tuples to store immutable sequences of values.

# %%
# Tuples are like lists BUT are IMMUTABLE

# practice with tuples
scores = [32, 55, 72, 91]   # a list is mutable
coordinates = (-3, 4, 7)    # a tuple is not mutable

# show that scores is mutable
scores[-1] = 100
print(scores)

coordinates = (5, 77, -3)     #re-assignment is OK
# show that tuples are not mutable     

#coordinates[-1] = 100.   #tuple not mutable
#print(coordinates)

scores_tuple = tuple(scores) # you can convert a list into a tuple
print(scores_tuple)


# Question:  Can tuples be sorted?
# Discuss with your neighbor

# coordinates.sort() # tuples are immutable
new_tuple = sorted(coordinates) # sorted makes a new object

# Takeaway: Write a note to yourself about tuples
# Out:
# [32, 55, 72, 100]
# (32, 55, 72, 100)

# %%
# reference:  https://www.w3schools.com/python/python_tuples.asp

# Why use tuples? 
#     keys in dictionaries must be immutable types
#     some data never changes : GPS coordinates

# %% [markdown]
# ### 21.3 Use namedtuple (immutable) and recordclass (mutable) to store user-defined data objects.

# %%
# namedtuple is useful for creating well-defined objects

# namedtuple is like a mix of tuples and dictionaries

# A namedtuple is like its own kind of type!
# its a Python convention to use a Capital letter when naming a namedtuple

from collections import namedtuple
# import collections...but we're not going to use other collection items

# define a namedtuple called Person
Person = namedtuple("Person", ["fname", "lname", "age"])

# make a single person....pls don't name it person !!
p1 = Person("Bucky", "Badger", 124)
print(p1.age)


# make a list of Persons
people=[
    Person("Alice", "Anderson", 30),  # positional arguments
    Person("Bob", "Baker", 31),
    # add two more Persons to people
    Person("Celia", "Answer", 21),
    Person("Marcus", "Carlson", 33)
    
]

person0 = people[0]
print("Hello " + person0.fname + " " + person0.lname)


# right here, add another Person by using keyword arguments 
person2 = Person(age=13, lname="Kuemmel", fname = "Stevie")

# add this person to your list....
people.append(person2)

# print out people
print(people)


for p in people:
    print("Hello " + p.fname + " " + p.lname)
# Out:
# 124
# Hello Alice Anderson
# [Person(fname='Alice', lname='Anderson', age=30), Person(fname='Bob', lname='Baker', age=31), Person(fname='Celia', lname='Answer', age=21), Person(fname='Marcus', lname='Carlson', age=33), Person(fname='Stevie', lname='Kuemmel', age=13)]
# Hello Alice Anderson
# Hello Bob Baker
# Hello Celia Answer
# Hello Marcus Carlson
# Hello Stevie Kuemmel

# %%
# Namedtuples have a deeper significance....the namedtuples we create are their own type

# %% [markdown]
# ![namedtuple.png](attachment:namedtuple.png)

# %%
# write a function to find the average age of the Persons in people
# Practice

def avg_age(p_list):
    # assume p_list is a list of Persons
    sum = 0

    return sum

avg_age(people)
# Out:
# 30
# 31
# 13
# 24.666666666666668

# %%
# demonstrate that namedtuples are immutable but lists of namedtuples are mutable

# Practice
# Out:
# 15

# %%
# recordclass is a mutable namedtuple
# recordclass needs to be installed using pip
# see lecture slides for the deets

# %% [markdown]
# ![recordclass.png](attachment:recordclass.png)

# %% [markdown]
# ### 21.4 Evaluate Python expressions that use 'is' and '==' to compare objects

# %%
# example 4a:  Is vs == 
# Copy and paste into Python Tutor
w = [1, 2, 3]
x = [4, 5, 6]
y = [4, 5, 6]
z = y


print(x == y)
print(x is y)
print(x == z)
print(y is z)



# takeaway:  what is the difference between is and == ? 
#  == checks if two objects contain the same information
#  IS checks if two references are to the same object
# Out:
# True
# False
# True
# True

# %%
# example 4b: Add this to Python Tutor
y.append(3)
print(x == y)
print(x is y)
print(x == z)
print(y is z)

# takeaway
# because y and z refer to the same object
# changes to y affect z
# Out:
# False
# False
# False
# True

# %%
# example 4c: Try this in Python Tutor
a = 20 * 40
b = 20 * 40   # change this
print(a == b)
print( a is b)

c = "ha"*10
d = "haha" * 5
print(c == d)
print(c is d)

# takeaway
# Python can optimize the storage of object
# de-duplication
# Out:
# True
# False
# True
# True

# %% [markdown]
# ### 21.5 Determine the side effects that occur when modifying parameters.

# %%
# example 5a:  try this in Python tutor
def f(x):
  x *= 3
  print("f:", x)

num = 10
f(num)
print("after:", num)

# takeaway:  what happens when a parameter is reassigned?
# Out:
# f: 30
# after: 10

# %%
# example 5b:  try in Python Tutor
def f(items):
  items.append("!!!")
  print("f:", items)

words = ['hello', 'world']
f(words)
print("after:", words)

# takeaway:  what happens when a list parameter is mutated ?
# Out:
# f: ['hello', 'world', '!!!']
# after: ['hello', 'world', '!!!']

# %%
# example 5c:  try in Python Tutor
def f(items):
  items = items + ["!!!"]
  print("f:", items)

words = ['hello', 'world']
f(words)
print("after:", words)

# takeaway:  what happens when a list parameter is reassigned ?
# Out:
# f: ['hello', 'world', '!!!']
# after: ['hello', 'world']

# %%
# example 5d:  try in Python Tutor
def first(items):
    return items[0]

def smallest(items):
    items.sort()
    return items[0]

numbers	= [4,5,3,2,1]
print("first:", first(numbers))
print("smallest:", smallest(numbers))
print("first:", first(numbers))

# takeaway:  what happens when a list parameter is sorted "in place" using .sort() ?
# Out:
# first: 4
# smallest: 1
# first: 1

# %%
# example 5e:  try in Python Tutor
def first(items):
    return items[0]

def smallest(items):
    items = sorted(items)
    return items[0]

numbers	= [4,5,3,2,1]
print("first:", first(numbers))
print("smallest:", smallest(numbers))
print("first:", first(numbers))

# takeaway:  what happens when a list parameter is sorted using sorted()?
# Out:
# first: 4
# smallest: 1
# first: 4

# %%
# Practice:  Try out some recordclass examples

# %% [markdown]
# ## After Lecture

# %%
# Interactive Exercises

# %%
# Check for Friday's worksheet answers (in link to Friday's code section) later today

# %%
# Read today's slides one more time, and try out the recordclass examples
