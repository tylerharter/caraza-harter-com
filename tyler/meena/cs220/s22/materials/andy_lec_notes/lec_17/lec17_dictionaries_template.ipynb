# %%
import csv

# %%
# Warmup 1: Read in the file 'cs220_survey_data.csv' into a lists of lists


# source:  Automate the Boring Stuff with Python Ch 12
def process_csv(filename):
    exampleFile = open(filename, encoding="utf-8")  
    exampleReader = csv.reader(exampleFile) 
    exampleData = list(exampleReader)        
    exampleFile.close()  
    return exampleData

survey_data = None # change this

# show the length of this list of lists
# Out:
# 721

# %%
# Warmup 2: store the first row in a variable called header
header = None
header
# Out:
# ['Lecture',
#  'Age',
#  'Primary major',
#  'Other majors',
#  'Zip Code',
#  'Pizza topping',
#  'Pet owner',
#  'Runner',
#  'Sleep habit',
#  'Procrastinator']

# %%
# Warmup 3: store the rest of the data in a variable called rows
rows = None
rows
# Out:
# [['LEC001',
#   '19',
#   'Business: Other',
#   '',
#   '53706',
#   'pepperoni',
#   'Yes',
#   'No',
#   'early bird',
#   'Yes'],
#  ['LEC001',
#   '21',
#   'Other',
#   'Economics/Philosophy, Data Science Certificate',
#   '53703',
#   'pepperoni',
#   'Yes',
#   'No',
#   'no preference',
#   'Yes'],
#  ['LEC003',
#   '19',
#   'Computer Science',
#   'Data science',
#   '53706',
#   'pineapple',
#   'Yes',
#   'Yes',
#   'night owl',
#   'Yes']]

# %%
# Warmup 4: show the last 3 rows of data

# %%
# Warmup 5: Write a function that counts the frequency of a value in a column

def count_col_frequency(value, col_name):
    ''' returns the frequency of value in col_name '''
    count = 0
    for row in rows:
        if row[header.index(col_name)] == value:
            count += 1
    return count

# %%
#test your function
count_col_frequency("pineapple", "Pizza topping")
# Out:
# 80

# %%
# Warmup 6: Think about it:  Is there an easy way to count *every* topping frequency?

# %% [markdown]
# ## March 7: Dictionaries
#
# Learning Objectives:
# - Use correct dictionary syntax
#  - to create a dictionary using either {} or dict()
#  - to lookup, insert, update, and pop key/value pairs
# - Use a for loop, the in operator, and common methods when working with dictionaries.
# - Write code that uses a dictionary
#  - to store frequencies
#  - to iterate through all key/value pairs

# %% [markdown]
# As we are getting more sophisticated in this course, its time to define...
# ### Data Structure <br>
# a data structure is a collection of data values, the relationships among them, and the functions or operations that can be applied to the data  (Wikipedia)
#
# Python contains built-in Data Structures called Collections
#
# ![collections.png](attachment:collections.png)
#
# Today you will learn how store data in Dictionaries.
#
# #### Dictionary <br>
# A dictionary is like a list, but more general. In a list, the indices have to be integers; but a dictionary they can be any **immutable** type.
#
# You can think of a dictionary as a mapping between a set of indices (which are called keys) and a set of values. Each key maps to a value. The association of a key and a value is called a key-value pair or sometimes an item.
#
# (from Think Python, Chapter 11)

# %%
# a dictionary that stores prices of bakery items
# create a dictionary of key/value pairs
# notice the curly brackets
# notice it can span over more than one line, indenting doesn't matter
price_dict = { 'pie': 3.95, 
         'ala mode':1.50, 
         'donut': 1.25,     'muffin': 2.25,
    'brownie': 3.15,
         'cookie': 0.79,  'milk':1.65, 'loaf': 5.99,
        'hot dog': 4.99}  # feel free to add some of your own here
price_dict
# Out:
# {'pie': 3.95,
#  'ala mode': 1.5,
#  'donut': 1.25,
#  'muffin': 2.25,
#  'brownie': 3.15,
#  'cookie': 0.79,
#  'milk': 1.65,
#  'loaf': 5.99,
#  'hot dog': 4.99}

# %%
# print the length of the dictionary
print(price_dict)      # number of key/value pairs

#get the price for a certain item
print(price_dict)  # name of dict [ key]

#get the price for donut
print(price_dict)

# what's wrong with this line? 
# print(price_dict[1.25])
# Out:
# 9
# 5.99
# 1.25

# %% [markdown]
# ### Dictionaries are Mutable

# %%
# add a new key/value pair using [ ] notation


# add one of your own
# Out:
# {'pie': 3.95,
#  'ala mode': 1.5,
#  'donut': 1.25,
#  'muffin': 2.25,
#  'brownie': 3.15,
#  'cookie': 0.79,
#  'milk': 1.65,
#  'loaf': 5.99,
#  'hot dog': 4.99,
#  'drink': 2.49}

# %%
# change the value associated with a key....syntax is like add



# now you add one
price_dict
# Out:
# {'pie': 3.95,
#  'ala mode': 1.5,
#  'donut': 1.25,
#  'muffin': 2.25,
#  'brownie': 3.15,
#  'cookie': 0.79,
#  'milk': 1.65,
#  'loaf': 5.99,
#  'hot dog': 4.99,
#  'drink': 2.99}

# %%
# use pop to delete a key/value pair
price_dict.pop('hot dog')  # or del(price_dict['hot dog'])

# delete another key/value pair
price_dict.pop()

# try deleting someting that is not there
#price_dict.pop('pizza')

# fix this with an if statement
if 'pizza' in price_dict:
    price_dict.pop('pizza')

# %%
# get all keys and convert to a list
print(price_dict.keys())
# Out:
# dict_keys(['pie', 'ala mode', 'donut', 'muffin', 'brownie', 'cookie', 'milk'])
# ['pie', 'ala mode', 'donut', 'muffin', 'brownie', 'cookie', 'milk']

# %%
# get all values and convert to a list
print(price_dict.values())
# Out:
# dict_values([3.95, 1.5, 1.25, 2.25, 3.15, 0.79, 1.65])
# [3.95, 1.5, 1.25, 2.25, 3.15, 0.79, 1.65]

# %%
# use 'in' price_dict, price_dict.keys(), price_dict.values()

#print('donut' in price_dict)  # default is to check the keys
#print(9.95 in price_dict)     # default is NOT values
#print('apple' in price_dict.keys())   # can call out the keys
#print(3.95 in price_dict.values())    # can check the values
# Out:
# True
# False
# False
# True

# %%
# Applications

# %%
# Example 1: given a list of items, find the total cost of the order
order = ['pie', 'donut', 'milk', 'cookie', 'tofu'] # add more items to the order
print(order)

total_cost = 0
for item in order:
    pass
        
# find the total of the items in the order
print ("Your total is ${:.2f}".format(total_cost))
# Out:
# ['pie', 'donut', 'milk', 'cookie', 'tofu']
# tofu is not in the dictionary
# Your total is $7.64

# %%
# Example 2a:  find the frequency of characters in a sentence

# start with an empty dictionary
letter_freq = {} 
# letter_freq = dict()   # other way

sentence = "Meet me at the bike racks after school at 3:30 today."

for letter in sentence:
    pass

print(letter_freq)
# Out:
# {'m': 2, 'e': 6, 't': 6, ' ': 10, 'a': 5, 'h': 2, 'b': 1, 'i': 1, 'k': 2, 'r': 2, 'c': 2, 's': 2, 'f': 1, 'o': 3, 'l': 1, '3': 2, ':': 1, '0': 1, 'd': 1, 'y': 1, '.': 1}

# %%
# Example 2b: find the letter that occurred the most
most_used_key = None  
max_value = 0
for key in letter_freq:
    pass

print("the character {} appeared {} times".format(str(most_used_key), max_value))
# Out:
# the character   appeared 10 times

# %%
# think about it...why did we use None ?    
# why use 0 ? 
# why not use for i in range?

for i in range (len(letter_freq)):
    print (i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-51a323b4acb5> in <module>
#       3 # why not use for i in range?
#       4
# ----> 5 for i in range (len(letter_freq)):
#       6     print (i)
#       7
#
# NameError: name 'letter_freq' is not defined

# %%
# Recall:  survey data
# rows
rows[-1]
# Out:
# ['LEC003',
#  '19',
#  'Computer Science',
#  'Data science',
#  '53706',
#  'pineapple',
#  'Yes',
#  'Yes',
#  'night owl',
#  'Yes']

# %%
# Example 3a. Same as 2a, but use the survey_data
major_freq = dict() # another way to make a dictionary

major_freq
# Out:
# {}

# %%
# Example 3b: use the algorithm from 2b to find the major with the highest frequency

# find the frequency of each major


print("the major {} appeared {} times".format(str(most_used_key), max_value))
# Out:
# the major Engineering appeared 328 times

# %% [markdown]
# ![Screen%20Shot%202022-03-07%20at%208.32.53%20AM.png](attachment:Screen%20Shot%202022-03-07%20at%208.32.53%20AM.png)

# %% [markdown]
# ### After Lecture

# %%
# 1. Read the slides to learn how dictionaries relate to lists and sets.

# %%
# 2. Review this summary of common dictionary methods...do not need to memorize
#    https://www.w3schools.com/python/python_ref_dictionary.asp
