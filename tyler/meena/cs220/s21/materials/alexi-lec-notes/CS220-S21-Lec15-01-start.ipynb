# %% [markdown]
# **Outline for Friday, February 26**
#
# Lists
#
# You will be able to:
#  - Read and write code that uses lists
#  - Identify that a list is a type of *sequence* & explain why this matters
#  - Use sequences in 3 new ways
#  - Explain the differences between Mutable and Immutable values
#
# Definitions:
#  - List
#  - Element
#  - Mutable
#
# Useful functions:
#  - sort()
#
# Reminders:
# - Quiz 4 due Friday. Project 5 is available and due next Wednesday.
# - If you are struggling with coursework due to COVID (or other illness) please let me know. Pandemic times can be a struggle and your health is more important to me than any class assignment.

# %% [markdown]
# **External reference (you won't be tested on this cell)**
# - If you were wondering _why_ "Z" < "a", here's the [ASCII table](http://www.asciitable.com/). Each letter in a string is secretly stored in memory as a number using this chart.

# %% [markdown]
# **List**
#
# Where a string is a sequence of characters (strings with length 1)...
#
# A list is a sequence of:

# %%
#List syntax

# %%
#Exercise: Calculate the sum of a list of numbers

# %% [markdown]
# Recall our list of things you can do with sequences:
# -    Calculate its length using the len()
# -    indexing: get the value AT a particular index in the sequence
# -    slicing: get the values at a range of the indexes in the sequence (example: a substring)
# -    for loop

# %% [markdown]
# Ven diagram of string and list capabilities:
#
# [](attachment:image.png)
# <img src="attachment:image.png" align="left" width="600" />

# %%
#Example list with different type elements
li = [True, False, 3, "hi", [1, 4]]

# %% [markdown]
# **Mutability**

# %% [markdown]
# **Transforming lists to strings and back again**

# %% [markdown]
# **Challenge Problems**
#
# FizzBuzz: Write a function that takes a number N and prints out each number from 1 to N (inclusive!) _except_ that multiples of 3 are replaced by "Fizz" and multiples of 5 are replaced by "Buzz".
#
# Median: Find the _index_ of the median value in a list of numbers. Don't change the original list!
